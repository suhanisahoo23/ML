# %% [markdown]
# # Create Custom Dataset

# %%
import pandas as pd

data = {
    'Hours': [1,2,3,4,5],
    'Marks': [20,40,60,80,100]
}
df = pd.DataFrame(data)
df.to_csv("dataset.csv", index=False)
print(df)
